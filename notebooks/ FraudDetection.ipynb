# %% [markdown]
# <a href="https://colab.research.google.com/github/t-ashriya/AI4ALL-Fraud-Detection/blob/main/notebooks/%20FraudDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load Dataset

# %%
path = "/content/drive/MyDrive/AI4All Team12D/Fraud_Detection/Datasets/fraudTrain.csv"

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
df = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11017/739166957.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv(path)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# Data Encoding

# %%
col = 'category'

encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded = encoder.fit_transform(df[[col]])
encoded_df = pd.DataFrame(
    encoded,
    columns=encoder.get_feature_names_out([col])
)

df_encoded = pd.concat([df.drop(columns=[col]), encoded_df], axis=1)

# %%
df_encoded.head(10)
df.head(10)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
# 5           5   2019-01-01 00:04:08  4767265376804500
# 6           6   2019-01-01 00:04:42    30074693890476
# 7           7   2019-01-01 00:05:08  6011360759745864
# 8           8   2019-01-01 00:05:18  4922710831011201
# 9           9   2019-01-01 00:06:01  2720830304681674
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# ...
